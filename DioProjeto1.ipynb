# %%
import pandas as pd

# %%
#error_bad_lines=False ignora erros ao carregar o arquivo.
df = pd.read_csv("/content/drive/MyDrive/DIO.me/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv",error_bad_lines=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
#Imprime as 5 primeiras linhas do arquivo
df.head()
# Out:
#         country;continent;year;lifeExp;pop;gdpPercap
# 0   Afghanistan;Asia;1952;28.801;8425333;779.4453145
# 1   Afghanistan;Asia;1957;30.332;9240934;820.8530296
# 2  Afghanistan;Asia;1962;31.997;10267083;853.1007...
# 3   Afghanistan;Asia;1967;34.02;11537966;836.1971382
# 4  Afghanistan;Asia;1972;36.088;13079460;739.9811...

# %%
#Imprime as 5 ultimas linhas do arquivo
df.tail()
# Out:
#            country;continent;year;lifeExp;pop;gdpPercap
# 3219  Zimbabwe;Africa;1987;62.351000000000006;921641...
# 3220   Zimbabwe;Africa;1992;60.377;10704340;693.4207856
# 3221  Zimbabwe;Africa;1997;46.809;11404948;792.44996...
# 3222  Zimbabwe;Africa;2002;39.989;11926563;672.03862...
# 3223  Zimbabwe;Africa;2007;43.487;12311143;469.70929...

# %%
# sep= Por padrão o separador é ",", neste caso usamos o ";" como separador.
df = pd.read_csv("/content/drive/MyDrive/DIO.me/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv",error_bad_lines=False, sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#Alterando nome das colunas no arquivo
df = df.rename(columns={"country":"País", "continent":"Continente", "year":"Ano", "lifeExp":"Exp de Vida", "pop":"Pop Total","gdpPercap":"PIB"})

# %%
#Informa o total de linhas e colunas
df.shape
# Out:
# (3312, 6)

# %%
df.columns
# Out:
# Index(['País', 'Continente', 'Ano', 'Exp de Vida', 'Pop Total', 'PIB'], dtype='object')

# %%
df.dtypes
# Out:
# País            object
# Continente      object
# Ano              int64
# Exp de Vida    float64
# Pop Total        int64
# PIB            float64
# dtype: object

# %%
df.describe()
# Out:
#                Ano  Exp de Vida     Pop Total            PIB
# count  3312.000000  3312.000000  3.312000e+03    3312.000000
# mean   1980.301630    65.246871  3.161489e+07   11317.115805
# std      16.927294    11.768412  1.041193e+08   11369.142739
# min    1950.000000    23.599000  5.941200e+04     241.165876
# 25%    1967.000000    58.337500  2.678572e+06    2514.625266
# 50%    1982.000000    69.610000  7.557218e+06    7838.505123
# 75%    1996.000000    73.657750  1.958522e+07   17357.879170
# max    2007.000000    82.670000  1.318683e+09  113523.132900

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
#Fazendo filtro utilizando a coluna continente, filtrando Africa.
df.loc[df["Continente"] == "Africa"]
# Out:
#           País Continente   Ano  Exp de Vida  Pop Total          PIB
# 24     Algeria     Africa  1952       43.077    9279525  2449.008185
# 25     Algeria     Africa  1957       45.685   10270856  3013.976023
# 26     Algeria     Africa  1962       48.303   11000948  2550.816880
# 27     Algeria     Africa  1967       51.407   12760499  3246.991771
# 28     Algeria     Africa  1972       54.518   14760787  4182.663766
# ...        ...        ...   ...          ...        ...          ...
# 3307  Zimbabwe     Africa  1987       62.351    9216418   706.157306
# 3308  Zimbabwe     Africa  1992       60.377   10704340   693.420786
# 3309  Zimbabwe     Africa  1997       46.809   11404948   792.449960
# 3310  Zimbabwe     Africa  2002       39.989   11926563   672.038623
# 3311  Zimbabwe     Africa  2007       43.487   12311143   469.709298
#
# [613 rows x 6 columns]

# %%
#Utilizando o nunique para fazer uma contagem de paises por continente.
df.groupby("Continente")["País"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: País, dtype: int64
